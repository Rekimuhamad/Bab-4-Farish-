# %% [markdown]
# <a href="https://colab.research.google.com/github/Rekimuhamad/Bab-4-Farish-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("halo, Reki")
# Out:
# halo, Reki
